# %% [markdown]
# # Week 2 Homework: Conditionals, Loops, and Functions
#
# **Due:** Before next Tuesday's class
# **Estimated Time:** 3-4 hours
# **Topics:** Decision Making, Repetition, Code Organization
#
# ## 📋 Instructions
# Complete all exercises below. Focus on applying the concepts you learned this week:
# - **Conditionals**: Making decisions with if/elif/else
# - **Loops**: Repeating actions with for/while loops
# - **Functions**: Organizing code into reusable blocks
#
# ---

# %% [markdown]
# ## Exercise 1: Conditional Logic Mastery (25 points)

# %%
# 1.1 Weather Advisory System (10 points)
# Create a system that provides weather advice based on multiple conditions

def weather_advisor(temperature, humidity, wind_speed, is_raining):
    """
    Provide weather advice based on conditions.
    
    Parameters:
    - temperature: int (Fahrenheit)
    - humidity: int (percentage 0-100)
    - wind_speed: int (mph)
    - is_raining: bool
    
    Return weather advice and activity recommendation
    """
    # Your implementation here
    # Consider these conditions:
    # - Temperature ranges: <32 (freezing), 32-60 (cold), 60-80 (comfortable), >80 (hot)
    # - High humidity: >70%
    # - High wind: >15 mph
    # - Combine multiple factors for comprehensive advice
    
    pass

# Test your function
test_cases = [
    (75, 45, 8, False),   # Nice day
    (95, 85, 5, False),   # Hot and humid
    (30, 60, 25, True),   # Cold, windy, and rainy
    (65, 40, 12, False)   # Pleasant conditions
]

for temp, humidity, wind, rain in test_cases:
    advice = weather_advisor(temp, humidity, wind, rain)
    print(f"Weather: {temp}°F, {humidity}% humidity, {wind} mph wind, {'Raining' if rain else 'Clear'}")
    print(f"Advice: {advice}\n")

# %%
# 1.2 Student Grade Calculator with Advanced Logic (15 points)
# Create a comprehensive grading system

def calculate_final_grade(homework_scores, quiz_scores, midterm_score, final_score, attendance_rate):
    """
    Calculate final grade with complex weighting and bonus system.
    
    Grading scheme:
    - Homework: 25% (average of all homework scores)
    - Quizzes: 20% (drop lowest, average the rest)
    - Midterm: 25%
    - Final: 30%
    - Attendance bonus: +2% if attendance >= 90%, +1% if >= 80%
    
    Return: (final_percentage, letter_grade, status)
    """
    # Your implementation here
    # Include logic for:
    # 1. Calculate weighted average
    # 2. Apply attendance bonus
    # 3. Determine letter grade (A: 90+, B: 80+, C: 70+, D: 60+, F: <60)
    # 4. Determine status (Honors: A+, Dean's List: A, Pass: C+, At Risk: D, Fail: F)
    
    pass

# Test the grading system
student_data = [
    ([95, 88, 92, 85], [78, 85, 92, 88, 90], 87, 91, 95),
    ([70, 75, 68, 80], [65, 70, 75, 80, 72], 73, 78, 85),
    ([85, 90, 88, 92], [88, 85, 90, 87, 89], 89, 93, 92)
]

for i, (hw, quizzes, midterm, final, attendance) in enumerate(student_data, 1):
    grade_info = calculate_final_grade(hw, quizzes, midterm, final, attendance)
    print(f"Student {i}: {grade_info}")

# %% [markdown]
# ## Exercise 2: Loop Mastery (30 points)

# %%
# 2.1 Data Analysis with Loops (15 points)
# Analyze sales data using various loop techniques

monthly_sales = [
    [1200, 1500, 1300, 1700, 1400],  # January
    [1100, 1600, 1800, 1200, 1350],  # February  
    [1400, 1300, 1900, 1600, 1500],  # March
    [1600, 1200, 1400, 1800, 1700],  # April
    [1500, 1700, 1600, 1400, 1550]   # May
]

months = ['January', 'February', 'March', 'April', 'May']

# Implement comprehensive sales analysis:

# 2.1a: Monthly analysis
print("=== Monthly Sales Analysis ===")
for i, month in enumerate(months):
    # Calculate and display for each month:
    # - Total sales
    # - Average daily sales
    # - Highest and lowest sales days
    # - Number of days above average
    pass

# 2.1b: Overall analysis
print("\n=== Overall Analysis ===")
# Calculate and display:
# - Best performing month
# - Worst performing month
# - Overall average daily sales
# - Total sales for all months
# - Growth trend (compare each month to previous)

# 2.1c: Advanced patterns
print("\n=== Sales Patterns ===")
# Find patterns using loops:
# - Days of the week performance (1st day of month vs 2nd day, etc.)
# - Identify weeks with consistent growth
# - Flag any unusual spikes or drops (>20% difference from month average)

# %%
# 2.2 Interactive Number Games (15 points)
# Create engaging number games using while loops

import random

def guessing_game_advanced():
    """
    Advanced number guessing game with multiple difficulty levels
    """
    print("🎯 Welcome to the Advanced Number Guessing Game!")
    
    # Let user choose difficulty
    difficulties = {
        'easy': (1, 50, 10),    # range 1-50, 10 attempts
        'medium': (1, 100, 7),  # range 1-100, 7 attempts
        'hard': (1, 200, 5)     # range 1-200, 5 attempts
    }
    
    # Your implementation here:
    # 1. Let user choose difficulty
    # 2. Generate secret number in appropriate range
    # 3. Track attempts and provide hints
    # 4. Give "warmer/colder" feedback
    # 5. Keep score across multiple games
    # 6. Ask if player wants to play again
    
    pass

def multiplication_drill():
    """
    Multiplication practice with progress tracking
    """
    print("🧮 Multiplication Drill Practice!")
    
    # Your implementation here:
    # 1. Ask user which times table to practice (2-12)
    # 2. Generate random problems
    # 3. Track correct/incorrect answers
    # 4. Provide encouragement
    # 5. Show final score and accuracy percentage
    # 6. Identify weak areas for additional practice
    
    pass

# Test your games (comment out when not testing)
# guessing_game_advanced()
# multiplication_drill()

# %% [markdown]
# ## Exercise 3: Function Design and Organization (25 points)

# %%
# 3.1 Banking System Functions (15 points)
# Create a comprehensive banking system using functions

# Global account database (in real systems, this would be a database)
accounts = {}
transaction_history = {}

def create_account(account_number, initial_balance=0, account_type='checking'):
    """
    Create a new bank account
    
    Parameters:
    - account_number: str
    - initial_balance: float (default 0)
    - account_type: str ('checking' or 'savings')
    
    Returns: bool (success/failure)
    """
    # Your implementation here
    # Validate inputs, create account, initialize transaction history
    pass

def deposit(account_number, amount):
    """
    Deposit money into an account
    
    Parameters:
    - account_number: str
    - amount: float
    
    Returns: bool (success/failure)
    """
    # Your implementation here
    # Validate amount, update balance, record transaction
    pass

def withdraw(account_number, amount):
    """
    Withdraw money from an account
    
    Parameters:
    - account_number: str
    - amount: float
    
    Returns: bool (success/failure)
    """
    # Your implementation here
    # Validate amount, check sufficient funds, update balance, record transaction
    pass

def transfer(from_account, to_account, amount):
    """
    Transfer money between accounts
    
    Parameters:
    - from_account: str
    - to_account: str  
    - amount: float
    
    Returns: bool (success/failure)
    """
    # Your implementation here
    # Validate both accounts exist, sufficient funds, perform transfer
    pass

def get_balance(account_number):
    """
    Get current account balance
    
    Parameters:
    - account_number: str
    
    Returns: float or None if account doesn't exist
    """
    # Your implementation here
    pass

def get_transaction_history(account_number, limit=10):
    """
    Get recent transaction history
    
    Parameters:
    - account_number: str
    - limit: int (number of recent transactions)
    
    Returns: list of transactions
    """
    # Your implementation here
    pass

def calculate_interest(account_number, annual_rate=0.02):
    """
    Calculate and apply interest to savings accounts
    
    Parameters:
    - account_number: str
    - annual_rate: float (default 2%)
    
    Returns: float (interest earned)
    """
    # Your implementation here
    # Only apply to savings accounts, calculate monthly interest
    pass

# Test your banking system
print("=== Banking System Test ===")

# Create test accounts
create_account("12345", 1000, "checking")
create_account("67890", 500, "savings")

# Test transactions
deposit("12345", 200)
withdraw("12345", 150)
transfer("12345", "67890", 300)

# Display results
print(f"Account 12345 balance: ${get_balance('12345')}")
print(f"Account 67890 balance: ${get_balance('67890')}")
print("Transaction history for 12345:")
for transaction in get_transaction_history("12345"):
    print(f"  {transaction}")

# %%
# 3.2 Text Processing Toolkit (10 points)
# Create a collection of text processing functions

def word_frequency(text, ignore_case=True):
    """
    Count word frequencies in text
    
    Parameters:
    - text: str
    - ignore_case: bool
    
    Returns: dict {word: count}
    """
    # Your implementation here
    pass

def find_longest_words(text, n=5):
    """
    Find the n longest words in text
    
    Parameters:
    - text: str
    - n: int (number of words to return)
    
    Returns: list of (word, length) tuples
    """
    # Your implementation here
    pass

def reading_time_estimate(text, wpm=200):
    """
    Estimate reading time for text
    
    Parameters:
    - text: str
    - wpm: int (words per minute, default 200)
    
    Returns: str (formatted time estimate)
    """
    # Your implementation here
    # Calculate and return formatted time (e.g., "3 minutes, 45 seconds")
    pass

def text_summary_stats(text):
    """
    Generate comprehensive text statistics
    
    Parameters:
    - text: str
    
    Returns: dict with various statistics
    """
    # Your implementation here
    # Return stats like: character count, word count, sentence count,
    # average word length, most common words, reading level estimate
    pass

# Test your text processing toolkit
sample_text = """
Python is a high-level, interpreted programming language with dynamic semantics. 
Its high-level built-in data structures, combined with dynamic typing and dynamic 
binding, make it very attractive for Rapid Application Development, as well as 
for use as a scripting or glue language to connect existing components together.
Python's simple, easy to learn syntax emphasizes readability and therefore reduces 
the cost of program maintenance. Python supports modules and packages, which 
encourages program modularity and code reuse.
"""

print("=== Text Processing Results ===")
print(f"Word frequencies: {word_frequency(sample_text)}")
print(f"Longest words: {find_longest_words(sample_text)}")
print(f"Reading time: {reading_time_estimate(sample_text)}")
print(f"Text statistics: {text_summary_stats(sample_text)}")

# %% [markdown]
# ## Exercise 4: Integration Challenge - Restaurant Management System (20 points)
#
# Combine all Week 2 concepts to create a comprehensive restaurant management system.

# %%
# Restaurant Management System - Setup
import random
from datetime import datetime, timedelta

# Restaurant data
menu = {
    'appetizers': {
        'nachos': {'price': 8.99, 'prep_time': 10, 'ingredients': ['chips', 'cheese', 'jalapeños']},
        'wings': {'price': 12.99, 'prep_time': 15, 'ingredients': ['chicken', 'sauce']},
        'salad': {'price': 7.99, 'prep_time': 5, 'ingredients': ['lettuce', 'tomato', 'dressing']}
    },
    'mains': {
        'burger': {'price': 14.99, 'prep_time': 20, 'ingredients': ['beef', 'bun', 'lettuce']},
        'pizza': {'price': 16.99, 'prep_time': 25, 'ingredients': ['dough', 'cheese', 'tomato sauce']},
        'pasta': {'price': 13.99, 'prep_time': 18, 'ingredients': ['pasta', 'sauce']}
    },
    'desserts': {
        'cake': {'price': 6.99, 'prep_time': 5, 'ingredients': ['flour', 'sugar', 'eggs']},
        'ice_cream': {'price': 4.99, 'prep_time': 2, 'ingredients': ['cream', 'sugar']}
    }
}

# Restaurant state
orders = []
daily_sales = []
inventory = {
    'chips': 50, 'cheese': 30, 'jalapeños': 20, 'chicken': 40,
    'sauce': 25, 'lettuce': 35, 'tomato': 30, 'dressing': 15,
    'beef': 25, 'bun': 30, 'dough': 20, 'tomato sauce': 25,
    'pasta': 30, 'flour': 40, 'sugar': 50, 'eggs': 24, 'cream': 20
}

print("Restaurant system initialized!")

# %%
# 4.1 Core Restaurant Functions

def display_menu(category=None):
    """
    Display restaurant menu with prices and prep times
    
    Parameters:
    - category: str or None (show specific category or all)
    """
    # Your implementation here
    # Format and display menu items with prices
    pass

def check_availability(item_name):
    """
    Check if an item can be prepared based on inventory
    
    Parameters:
    - item_name: str
    
    Returns: bool
    """
    # Your implementation here
    # Check if all required ingredients are in stock
    pass

def calculate_order_total(order_items):
    """
    Calculate total price for an order including tax and tip
    
    Parameters:
    - order_items: list of item names
    
    Returns: dict with subtotal, tax, suggested_tip, total
    """
    # Your implementation here
    # Calculate subtotal, add 8.5% tax, suggest 18% tip
    pass

def process_order(customer_name, order_items, customer_type='regular'):
    """
    Process a complete order with validation and inventory updates
    
    Parameters:
    - customer_name: str
    - order_items: list of item names
    - customer_type: str ('regular', 'vip', 'student')
    
    Returns: dict with order details and status
    """
    # Your implementation here
    # 1. Validate all items are available
    # 2. Calculate total with any applicable discounts
    # 3. Update inventory
    # 4. Estimate preparation time
    # 5. Generate order ID and add to orders list
    
    # Discount logic:
    # VIP customers: 10% off
    # Students: 15% off
    # Orders over $50: 5% off
    pass

def update_inventory(item_name, quantity_used):
    """
    Update inventory after item preparation
    
    Parameters:
    - item_name: str
    - quantity_used: int
    """
    # Your implementation here
    # Reduce inventory quantities for all ingredients used
    pass

def generate_daily_report():
    """
    Generate comprehensive daily sales and operations report
    
    Returns: dict with report data
    """
    # Your implementation here
    # Calculate: total sales, number of orders, popular items,
    # low inventory alerts, average order value
    pass

print("Core restaurant functions defined!")

# %%
# 4.2 Restaurant Simulation
# Create a simulation of a busy restaurant day

def simulate_customer_orders(num_customers=50):
    """
    Simulate a day's worth of customer orders
    
    Parameters:
    - num_customers: int
    """
    customer_names = [
        "Alice", "Bob", "Charlie", "Diana", "Eve", "Frank", "Grace", "Henry",
        "Iris", "Jack", "Kate", "Liam", "Maya", "Noah", "Olivia", "Paul"
    ]
    
    customer_types = ['regular', 'vip', 'student']
    
    print(f"=== Simulating {num_customers} customer orders ===")
    
    # Your implementation here:
    # 1. Loop through customers
    # 2. Generate random orders (1-4 items per customer)
    # 3. Randomly assign customer types
    # 4. Process each order
    # 5. Handle cases where items are unavailable
    # 6. Track successful vs failed orders
    
    for i in range(num_customers):
        # Generate random customer and order
        customer_name = random.choice(customer_names)
        customer_type = random.choice(customer_types)
        
        # Generate random order (your code here)
        pass
    
    # Display simulation results
    print(f"\nSimulation complete! Processed {len(orders)} orders.")
    return len(orders)

def analyze_restaurant_performance():
    """
    Analyze the restaurant's performance after the simulation
    """
    print("\n=== Restaurant Performance Analysis ===")
    
    # Your implementation here:
    # Analyze using loops and conditionals:
    # 1. Most popular menu items
    # 2. Revenue by category
    # 3. Peak order times
    # 4. Customer type analysis
    # 5. Inventory status and restock needs
    # 6. Profitability analysis
    
    pass

def recommend_menu_changes():
    """
    Use conditional logic to recommend menu or pricing changes
    """
    print("\n=== Menu Recommendations ===")
    
    # Your implementation here:
    # Use conditionals to make recommendations:
    # - If an item sells poorly, suggest removal or discount
    # - If an item sells very well, suggest price increase
    # - If certain combinations are popular, suggest combo meals
    # - If inventory runs low frequently, suggest supplier changes
    
    pass

# Run the complete restaurant simulation
print("🍽️ Starting Restaurant Management System Demo")

# Display menu
display_menu()

# Run simulation
orders_processed = simulate_customer_orders(30)

# Generate reports
daily_report = generate_daily_report()
print(f"\nDaily Report: {daily_report}")

# Analysis
analyze_restaurant_performance()
recommend_menu_changes()

print("\n🎉 Restaurant management system demo complete!")

# %% [markdown]
# ## 🌟 Bonus Challenges (Optional - +15 points)
#
# Push your skills further with these advanced challenges:

# %%
# Bonus 1: Advanced Algorithm Implementation (5 points)
# Implement sorting and searching algorithms using loops and conditionals

def bubble_sort(numbers):
    """
    Implement bubble sort algorithm
    
    Parameters:
    - numbers: list of integers
    
    Returns: sorted list and number of swaps performed
    """
    # Your implementation here
    pass

def binary_search(sorted_list, target):
    """
    Implement binary search algorithm
    
    Parameters:
    - sorted_list: list of sorted integers
    - target: integer to find
    
    Returns: index of target or -1 if not found
    """
    # Your implementation here
    pass

# Test the algorithms
test_numbers = [64, 34, 25, 12, 22, 11, 90]
sorted_numbers, swaps = bubble_sort(test_numbers.copy())
print(f"Bubble sort result: {sorted_numbers} (swaps: {swaps})")

index = binary_search(sorted_numbers, 25)
print(f"Binary search for 25: index {index}")

# %%
# Bonus 2: Password Security System (5 points)
# Create a comprehensive password management system

import string
import random

def generate_secure_password(length=12, include_symbols=True):
    """
    Generate a cryptographically secure password
    
    Parameters:
    - length: int (minimum 8)
    - include_symbols: bool
    
    Returns: str (secure password)
    """
    # Your implementation here
    # Ensure password contains:
    # - At least one uppercase letter
    # - At least one lowercase letter  
    # - At least one digit
    # - At least one symbol (if requested)
    pass

def check_password_strength(password):
    """
    Comprehensive password strength checker
    
    Parameters:
    - password: str
    
    Returns: dict with strength score and recommendations
    """
    # Your implementation here
    # Check multiple criteria:
    # - Length (8+ chars)
    # - Character variety
    # - No common patterns
    # - No dictionary words
    # - No keyboard patterns
    # Return score 0-100 and specific recommendations
    pass

def password_manager_system():
    """
    Interactive password management system
    """
    print("🔐 Advanced Password Management System")
    
    # Your implementation here:
    # Create interactive menu with options:
    # 1. Generate new password
    # 2. Check password strength
    # 3. Test multiple passwords
    # 4. Password improvement suggestions
    # Use loops for menu and input validation
    pass

# Test the password system
test_passwords = [
    "password123",
    "MyP@ssw0rd!",
    "Tr0ub4dor&3",
    "abc"
]

for pwd in test_passwords:
    strength = check_password_strength(pwd)
    print(f"Password '{pwd}': {strength}")

# Uncomment to run interactive system
# password_manager_system()

# %%
# Bonus 3: Game Development - Tic Tac Toe with AI (5 points)
# Create a complete Tic Tac Toe game with basic AI

def create_board():
    """Create empty 3x3 game board"""
    return [[' ' for _ in range(3)] for _ in range(3)]

def display_board(board):
    """Display the current game board"""
    # Your implementation here
    pass

def check_winner(board):
    """
    Check if there's a winner
    
    Returns: 'X', 'O', 'tie', or None
    """
    # Your implementation here
    # Check rows, columns, and diagonals
    pass

def get_available_moves(board):
    """Get list of available moves (row, col)"""
    # Your implementation here
    pass

def make_move(board, row, col, player):
    """Make a move on the board"""
    # Your implementation here
    pass

def ai_move(board, difficulty='easy'):
    """
    AI makes a move based on difficulty
    
    easy: random moves
    medium: block player wins, take easy wins
    hard: minimax algorithm (optional)
    """
    # Your implementation here
    pass

def play_tic_tac_toe():
    """Main game loop"""
    print("🎮 Tic Tac Toe Game!")
    
    # Your implementation here:
    # 1. Initialize board
    # 2. Choose game mode (human vs human, human vs AI)
    # 3. Main game loop with input validation
    # 4. Check for wins/ties after each move
    # 5. Ask to play again
    pass

# Uncomment to play the game
# play_tic_tac_toe()

# %% [markdown]
# ## 📝 Reflection Questions
#
# Answer these questions about your learning experience:
#
# ### Technical Understanding
# 1. **Conditionals**: Describe a situation where you used nested if-elif-else statements. Why was this approach better than alternatives?
#
# 2. **Loops**: Compare for loops vs while loops. When would you choose one over the other?
#
# 3. **Functions**: How did functions help you organize your code in the restaurant management system? Give specific examples.
#
# ### Problem Solving
# 4. **Debugging**: What was the most challenging bug you encountered? How did you solve it?
#
# 5. **Algorithm Design**: In the sales analysis exercise, how did you approach breaking down the complex requirements into smaller, manageable pieces?
#
# 6. **Code Reusability**: Give an example of where you created a function that you used multiple times. How did this improve your code?
#
# ### Application
# 7. **Real-world Connections**: How could the restaurant management system concepts apply to other domains (e.g., library systems, inventory management)?
#
# 8. **Future Learning**: What programming concepts would you like to explore next? How do they build on what you've learned?
#
# **Your Answers:**
#
# (Write your thoughtful responses here)
#
# ---

# %% [markdown]
# ## 📋 Submission Checklist
#
# Before submitting, verify:
#
# ### Code Quality
# - [ ] All functions have proper docstrings
# - [ ] Code is well-commented and readable
# - [ ] Variable names are descriptive
# - [ ] No syntax errors or runtime crashes
# - [ ] Edge cases are handled appropriately
#
# ### Functionality
# - [ ] Exercise 1: Both conditional systems work correctly
# - [ ] Exercise 2: Data analysis and games function properly
# - [ ] Exercise 3: Banking and text processing systems complete
# - [ ] Exercise 4: Restaurant system demonstrates integration
# - [ ] All test cases produce expected output
#
# ### Learning Demonstration
# - [ ] Effective use of conditionals for decision making
# - [ ] Proper implementation of loops for repetitive tasks
# - [ ] Functions used to organize and reuse code
# - [ ] Integration of multiple concepts in complex systems
# - [ ] Thoughtful reflection on learning experience
#
# ### Optional Bonus
# - [ ] Attempted at least one bonus challenge
# - [ ] Bonus implementations demonstrate advanced understanding
# - [ ] Creative solutions to complex problems
#
# **Estimated completion time:** 3-4 hours
# **Excellence requires:** Clear thinking, systematic problem-solving, and creative application! 🚀
#
# ---
#
# ## 🎯 Week 2 Learning Objectives Review
#
# By completing this homework, you have demonstrated:
#
# ✅ **Decision Making**: Using conditionals to create adaptive, intelligent programs
# ✅ **Repetition Control**: Implementing loops for efficient data processing and user interaction
# ✅ **Code Organization**: Designing functions for modularity, reusability, and maintainability
# ✅ **Problem Decomposition**: Breaking complex systems into manageable components
# ✅ **Integration Skills**: Combining multiple concepts to solve real-world problems
#
# **🎉 Congratulations on completing Week 2! You're building serious programming skills!** 🐍✨
